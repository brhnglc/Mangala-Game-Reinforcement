# %%
import gym
from gym import spaces
import random
import sys

#PyGame screen sizes
WIDTH,HEIGHT = 800, 600



class MangalaEnv(gym.Env):

    def convert_move(self, move, player):
        """
        Girdilerin pocket karşılıklarına çevrilmesi
        """
        if player == 1:
            return move
        if player == 2:
            return move+7
        return False

    def valid_move(self, pocket_position, player):
        """
        Hamle yapılıcak taş var mı diye kontrol ediliyor
        """
        player_1_side = (0 <= pocket_position <= 5)
        player_2_side = (7 <= pocket_position <= 12)

        if self.pockets[pocket_position] > 0:
            if player_1_side and player==1:
                return True
            if player_2_side and player==2:
                return True

        return

    def initialize_board(self):
        """
        Tahtanın doğru degerlerde başlatılması
        """
        num_stones_on_start = 4
        pockets = [num_stones_on_start]*14
        pockets[6] = 0
        pockets[13] = 0

        return pockets

    def check_game_over(self):
        """ Bir tarafın kuyusunda taş kalmaması durumunda oyunun bitmesi ve karşı
        tarafta taş kalması durumunda taşlarını bitiren oyuncunun hazinesinde toplanması
        """

        game_over = False

        empty_player_1 = sum(self.pockets[:6]) == 0
        empty_player_2 = sum(self.pockets[7:13]) == 0

        if empty_player_2:
            self.pockets[13] += sum(self.pockets[:6])
            self.pockets[:6] = [0]*6
            game_over = True

        if empty_player_1:
            self.pockets[6] += sum(self.pockets[7:13])
            self.pockets[7:13] = [0]*6
            game_over = True

        return game_over

    def determine_winner(self):
        """ Hazine durumlarına göre kazananın belirlenmesi
        """
        if self.pockets[13]>self.pockets[6]:
            return "Player 2"
        elif self.pockets[13]<self.pockets[6]:
            return "Player 1"
        return "Draw"

    def switch_player(self, player):
        """
        Tur geçişlerinde oyuncu geçişi
        """

        if player == 1:
            return 2
        return 1

    def capture(self, pocket_position, mangala_pocket,turn):
        """ pocket position : oynanan hamle
            mangala pocket : aktif oyuncunun hazinesin indexi

            eger oynanan son taş kendi boş kuyusuna denk geliyorsa
            ve de kuyunun karşıt kuyusu doluysa hem kendi kuyusundaki hemde
            karşıt kuyudaki taşları hazinesine eklenmesi
        """
        
        reward = 0
        opposite_pocket_dict = {0: 12, 1:11, 2:10, 3:9, 4:8, 5:7,
                                7:5, 8:4, 9:3, 10:2, 11:1, 12:0}
        if(self.pockets[opposite_pocket_dict[pocket_position]] != 0):
            opposite_pocket = opposite_pocket_dict[pocket_position]
            if(self.pockets[pocket_position] == 0 and self.pockets[opposite_pocket] == 0):
                return False,0
            self.pockets[mangala_pocket] += self.pockets[pocket_position]
            reward += self.pockets[pocket_position]
            self.pockets[pocket_position] = 0
            

            self.pockets[mangala_pocket] += self.pockets[opposite_pocket]
            reward += self.pockets[pocket_position]
            self.pockets[opposite_pocket] = 0

        return True,reward
    
    def capture_even(self,pocket_position,mangala_pocket,turn):
        """
        Eger oyuncunun son taşı rakibin kuyusundaki taşların toplamını çift yapıyorsa
        o kuyudaki tüm taşları hazinesine katar.
        """
        reward = 0
        if(self.pockets[pocket_position] == 0):
            return False,0
        
        self.pockets[mangala_pocket] += self.pockets[pocket_position]
        reward = self.pockets[pocket_position]
        self.pockets[pocket_position] = 0
        

        return True,reward

    def simulate_move(self, pocket_position, player):
        """
        Seçilen hamlenin oynanması
        """
        reward = 0
        capture_amnt_p1 = 0
        capture_amnt_p2 = 0
        go_again_amnt = 0
        pockets = self.pockets
        #Geriye bir taş bırakma ve eger hazinede tek taş varsa sağa taşıma
        stones_drawn = pockets[pocket_position] #eldeki taş sayısı
        if(stones_drawn == 1):
            pockets[pocket_position] = 0
        elif(stones_drawn != 0):
            pockets[pocket_position] = 1
            stones_drawn -= 1

        # Hamle yapılan kuynun sağa doğru birer birer bırakılarak ilerlenmesi
        while stones_drawn > 0:
            pocket_position += 1

            if pocket_position > len(pockets)-1:
                pocket_position = 0


            #Karşıdakinin kuyusuna gelinmesi durumunda bir sonraki kuyuya geçme
            mangala_1_position = pocket_position==6
            mangala_2_position = pocket_position==13
            player_1 = player == 1
            player_2 = player == 2
            player1_capture_true = False
            player2_capture_true = False
            if mangala_1_position and player_2:
                continue
            if mangala_2_position and player_1:
                continue

            # Taşları bırakma
            pockets[pocket_position] += 1
            stones_drawn -= 1

        #çift sayı yaptı mı
        end_with_even = pockets[pocket_position] % 2 == 0

        # Son hamlenin kendi kuyusunda bitirilmesi
        end_on_player_1_side = (0 <= pocket_position <= 5)
        end_on_player_2_side = (7 <= pocket_position <= 12)

        #son taşa gelinmesi durumu kontrolü
        stone_was_empty = pockets[pocket_position] == 1

        #boş kuyuya gelinmesi durumunda capture
        # Player 1 capture
        if player_1 and end_on_player_1_side and stone_was_empty:
            player1_capture_true,rwrd = self.capture(pocket_position, 6,"1")
            if(rwrd != 0):
                reward += 0.01
        # Player 2 capture
        if player_2 and end_on_player_2_side and stone_was_empty:
            player2_capture_true,rwrd = self.capture(pocket_position, 13,"2")
            if(rwrd != 0):
                reward -= 0.01
            
        if player1_capture_true:
            capture_amnt_p1 +=1
        if player2_capture_true:
            capture_amnt_p2 +=1

        #çift yapma durumuna göre captur
        if player_1 and end_on_player_2_side and end_with_even:
            player1_capture_true,rwrd =self.capture_even(pocket_position,6,"1")
            if(rwrd != 0):
                reward += 0.01
        if player_2 and end_on_player_1_side and end_with_even:
            player2_capture_true,rwrd = self.capture_even(pocket_position,13,"2")
            if(rwrd != 0):
                reward -= 0.01
        if(player1_capture_true):
            capture_amnt_p1 +=1
        if(player2_capture_true):
            capture_amnt_p2 +=1


        # son taşın kendi kuyusuna gelme durumu göz önünde bulundurarak hamlenin kime gecicegi
        if mangala_1_position and player_1:
            next_player = player
            go_again_amnt +=1
            reward += 0.01
        elif mangala_2_position and player_2:
            next_player = player
        else:
            next_player = self.switch_player(player)

        game_over = self.check_game_over()

        return next_player, game_over ,capture_amnt_p1,capture_amnt_p2,go_again_amnt,reward


    def turn_table(self,pockets):
        return pockets[7:]+pockets[:7]
    
    def show_end_game_alert(self,winner):
        """
        Render mode human iken oyunun bitmesi durumunda kimin kazandıgını gösteren ekran ve sistemin kapatılması
        """
#         if(self.render_mode == "human"):
#             pygame.quit()  
#             pygame.init()
            
#             screen = pygame.display.set_mode((400, 100))
#             pygame.display.set_caption("Mancala Game End")
#             screen.fill((255, 253, 208))
#             font = pygame.font.Font(None, 30)
#             text = font.render(f"Player {winner} wins! Press 'Esc' to exit.", True, "black")
#             screen.blit(text, (30, 30))
#             pygame.display.flip()    
#             waiting = True
#             while waiting:
#                 for event in pygame.event.get():
#                     if (event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE) or event.type == pygame.QUIT:
#                         pygame.quit()
#                         sys.exit()

    


    #GYM ENV

    def __init__(self):
        super(MangalaEnv, self).__init__()

        self.prev_mov1 = -1
        self.prev_mov2 = -1
        self.render_mode = "train"
        # Define action and observation space
        self.action_space = spaces.Discrete(6)  # 6 possible pockets
        self.observation_space = spaces.Box(low=0, high=48, shape=(14,), dtype=int)

        # Initialize the board
        self.pockets = self.initialize_board()
        self.player_turn = random.randint(1, 2)
        self.game_over = False
        
        self.capture_amount = 0
        self.capture_amount_p1 = 0
        self.capture_amount_p2 = 0
    def reset(self):
        # Reset the board

        self.pockets = self.initialize_board()
        self.player_turn = random.randint(1, 2)
        self.game_over = False
        self.capture_amount_p1 = 0
        self.capture_amount_p2 = 0
        self.go_again_amount = 0
        
#         if self.render_mode == 'human':
#             pygame.init()
#             self.screen = pygame.display.set_mode((WIDTH, HEIGHT))
#             pygame.display.set_caption("Mancala Game")
#             self.clock = pygame.time.Clock()
#             self.font = pygame.font.Font(None, 36)
#             self.render()



        return self.get_observation()

    def step(self, action):
        reward = 0
        move = self.convert_move(action, self.player_turn)
        if not self.valid_move(move, self.player_turn):
            #print("INVALID MOVE")
            return self.get_observation(), 0, False, {}


        if(self.player_turn == 1):
            self.prev_mov1 = move+1
           #print("prev_mov1",self.prev_mov1)
        if(self.player_turn == 2):
            self.prev_mov2 = move-7+1
            #print("prev_mov2",self.prev_mov2)


        next_player, game_over,capture_amnt_p1,capture_amnt_p2,go_again_amnt,rwrd = self.simulate_move(move, self.player_turn)
        
        
        self.capture_amount_p1 += capture_amnt_p1
        self.capture_amount_p2 += capture_amnt_p2
        self.go_again_amount += go_again_amnt
        
        self.player_turn = next_player
        self.game_over = game_over
        reward += rwrd
        if game_over:
            winner = self.determine_winner()
            if winner == "Player 1":
                self.show_end_game_alert("1")
                reward += 10
                
                #print("Player 1 Win"+"n"+"n"*5)
            elif winner == "Player 2":
                self.show_end_game_alert("2")
                reward += -10
                #print("Player 2 Win"+"n"+"n"*5)

        if self.render_mode == 'human':
            self.render(move=move)

        return self.get_observation(), reward, game_over, {}

    def render(self,move="none"):
        pass
#         if(self.render_mode == "human"):
#             #print("prev1->",self.prev_mov1,"prev2->",self.prev_mov2)
#                      # array to pocket res move 
#             upper_pockets = self.pockets[:6]
#             lower_pockets = self.pockets[7:-1]
    
#             upper_pockets_marker = [6, 5, 4, 3, 2, 1]
#             lower_pockets_marker = [1, 2, 3, 4, 5, 6]
#             mancala_1 = self.pockets[-1]
#             mancala_2 = self.pockets[6]
#             self.screen.fill("white")
#             # Oyuncu turn yazısı
#             turn_text = self.font.render("Player {}'s Turn".format(self.player_turn), True, "black")
#             self.screen.blit(turn_text, (10, 10))
#             # Tahta çizimi
#             pygame.draw.rect(self.screen, "black", (50, 50, 700, 500), 2)
#             # Pockets çizimi
            
#             color1,color2 = "black","black"
#             for i in range(6):
#                 if(i == self.prev_mov1-1):
#                     color1 = "blue"
#                 else:
#                     color1 = "black"
#                 if(i == self.prev_mov2-1):
#                     color2 = "red"
#                 else:
#                     color2 = "black"
                    
#                 pygame.draw.rect(self.screen, "black", (100 + i * 100, 100, 100, 100), 2)
#                 pygame.draw.rect(self.screen, "black", (100 + i * 100, 300, 100, 100), 2)
#                 pygame.draw.rect(self.screen, "black", (100 + i * 100, 100, 100, 200), 2)
#                 upper_stones_marker = self.font.render(str(upper_pockets_marker[i]), True, "gray")
#                 lower_stones_marker = self.font.render(str(lower_pockets_marker[i]), True, "gray")
#                 self.screen.blit(upper_stones_marker, (140 + i * 100, 80))
#                 self.screen.blit(lower_stones_marker, (140 + i * 100, 400))
#                 upper_stones = self.font.render(str(upper_pockets[i]), True, color1)
#                 lower_stones = self.font.render(str(lower_pockets[i]), True, color2)
#                 self.screen.blit(upper_stones, (640 - i * 100, 140))
#                 self.screen.blit(lower_stones, (140 + i * 100, 340))
#             # Mancala çizimi
#             mancala_1_text = self.font.render(str(mancala_1), True, "black")
#             mancala_2_text = self.font.render(str(mancala_2), True, "black")
#             self.screen.blit(mancala_1_text, (730, 250))
#             self.screen.blit(mancala_2_text, (55, 250))
#             pygame.display.flip()
            

    def close(self):
        pass
#         if(self.render_mode == "human"):
#              pygame.quit()
#              sys.exit()


    def get_observation(self):
        return self.pockets


 #3.29

# %%
import time

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

env = MangalaEnv()
    
input_size = len(env.get_observation())
output_size = env.action_space.n

models = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        models.extend([os.path.join(dirname, filename)])

#9 model var
import pandas as pd 

df = pd.DataFrame(models,columns=["model_name"])
df["score"] = 0

df["name_sort"]= df.model_name.apply(lambda x :x[40:])
import random
x1 = df.model_name.values
x2 = df.model_name.values
    
for i in range(0,1000000):
    selection_1 = 0
    selection_2 = 0

    selection_1 = random.choice(x1)
    selection_2 = random.choice(x2)

   
        
    loaded_model = DQN(input_size, output_size)

    loaded_model.load_state_dict(torch.load(selection_1)) 
    loaded_model.eval() 

    loaded_model2 = DQN(input_size, output_size)
    loaded_model2.load_state_dict(torch.load(selection_2)) 
    loaded_model2.eval()

    state = torch.tensor([env.reset()], dtype=torch.float32)
    while True:    
        if(env.player_turn == 1):
            raw_act = loaded_model(state) 
            enum_raw_act = list(enumerate(raw_act[0].detach().numpy()))
            sorted_enum_raw_act = list(reversed(sorted(enum_raw_act, key=lambda x: x[1])))
            action2 = "none"
            state_np = state.detach().numpy()[0]
            enum_raw_act = list(enumerate(raw_act[0].detach().numpy()))
            sorted_enum_raw_act = list(reversed(sorted(enum_raw_act, key=lambda x: x[1])))

            action = "none"
            state_np = state.detach().numpy()[0]
            state_pos = 0
            for i,_ in sorted_enum_raw_act:
                state_pos = i
                if(state_np[state_pos] != 0):
                    action = i
                    break        
            next_state, reward, done, _ = env.step(action)
            state = torch.tensor([next_state], dtype=torch.float32)
            #print("observation->",state,"action->",action,"reward->",reward)

        else:
            raw_act = loaded_model2(torch.tensor([env.turn_table(env.get_observation())], dtype=torch.float32)) 
            enum_raw_act = list(enumerate(raw_act[0].detach().numpy()))
            sorted_enum_raw_act = list(reversed(sorted(enum_raw_act, key=lambda x: x[1])))
            action2 = "none"
            state_np = state.detach().numpy()[0]
            enum_raw_act = list(enumerate(raw_act[0].detach().numpy()))
            sorted_enum_raw_act = list(reversed(sorted(enum_raw_act, key=lambda x: x[1])))

            action = "none"
            state_np = state.detach().numpy()[0]
            state_pos = 0
            for i,_ in sorted_enum_raw_act:
                state_pos = i+7
                if(state_np[state_pos] != 0):
                    action = i
                    break        

            next_state, reward, done, _ = env.step(action)
            state = torch.tensor([next_state], dtype=torch.float32)
            #print("observation->",state,env.turn_table(env.get_observation()),"action->",action,"reward->",reward)
        if done:
            #print("done")
            state = env.get_observation()
            if(state[13]> state[6]):
                df.loc[df.model_name==selection_2,["score"]] += 3
                df.loc[df.model_name==selection_1,["score"]] -= 3
            elif(state[13]<state[6]):
                df.loc[df.model_name==selection_1,["score"]] += 3
                df.loc[df.model_name==selection_2,["score"]] -= 3
            break
    if(i%500 == 0):
        print(df.iloc[:,1:].sort_values(by=["score"],ascending=False)[:5])

print(f"Total Test Reward: {total_reward}")
# Out:
#     score                            name_sort
# 11      6   /260000-trained_model-17-15_18.pth
# 13      3   /180000-trained_model-17-17_03.pth
# 23      3  /1670000-trained_model-17-00_11.pth
# 3       3   /230000-trained_model-13-12_37.pth
# 22      3   /830000-trained_model-14-04_41.pth
#     score                           name_sort
# 14      9  /160000-trained_model-17-16_12.pth
# 3       6  /230000-trained_model-13-12_37.pth
# 22      6  /830000-trained_model-14-04_41.pth
# 16      6  /340000-trained_model-17-17_08.pth
# 11      6  /260000-trained_model-17-15_18.pth
#     score                           name_sort
# 3      18  /230000-trained_model-13-12_37.pth
# 16     18  /340000-trained_model-17-17_08.pth
# 14     15  /160000-trained_model-17-16_12.pth
# 10     12  /130000-trained_model-13-09_42.pth
# 0       6  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 14     30  /160000-trained_model-17-16_12.pth
# 16     21  /340000-trained_model-17-17_08.pth
# 3      18  /230000-trained_model-13-12_37.pth
# 10     18  /130000-trained_model-13-09_42.pth
# 11      9  /260000-trained_model-17-15_18.pth
#     score                           name_sort
# 14     39  /160000-trained_model-17-16_12.pth
# 10     30  /130000-trained_model-13-09_42.pth
# 3      21  /230000-trained_model-13-12_37.pth
# 16     18  /340000-trained_model-17-17_08.pth
# 22     18  /830000-trained_model-14-04_41.pth
#     score                           name_sort
# 14     42  /160000-trained_model-17-16_12.pth
# 10     30  /130000-trained_model-13-09_42.pth
# 3      24  /230000-trained_model-13-12_37.pth
# 16     21  /340000-trained_model-17-17_08.pth
# 22     15  /830000-trained_model-14-04_41.pth
#     score                           name_sort
# 14     51  /160000-trained_model-17-16_12.pth
# 10     42  /130000-trained_model-13-09_42.pth
# 3      39  /230000-trained_model-13-12_37.pth
# 16     21  /340000-trained_model-17-17_08.pth
# 1      15  /130000-trained_model-17-00_44.pth
#     score                           name_sort
# 14     51  /160000-trained_model-17-16_12.pth
# 10     42  /130000-trained_model-13-09_42.pth
# 3      42  /230000-trained_model-13-12_37.pth
# 16     24  /340000-trained_model-17-17_08.pth
# 22     15  /830000-trained_model-14-04_41.pth
#     score                            name_sort
# 10     51   /130000-trained_model-13-09_42.pth
# 14     51   /160000-trained_model-17-16_12.pth
# 3      48   /230000-trained_model-13-12_37.pth
# 16     21   /340000-trained_model-17-17_08.pth
# 23     21  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10     54   /130000-trained_model-13-09_42.pth
# 14     51   /160000-trained_model-17-16_12.pth
# 3      48   /230000-trained_model-13-12_37.pth
# 23     24  /1670000-trained_model-17-00_11.pth
# 16     21   /340000-trained_model-17-17_08.pth
#     score                            name_sort
# 14     57   /160000-trained_model-17-16_12.pth
# 3      54   /230000-trained_model-13-12_37.pth
# 10     54   /130000-trained_model-13-09_42.pth
# 23     27  /1670000-trained_model-17-00_11.pth
# 1      24   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10     69   /130000-trained_model-13-09_42.pth
# 14     63   /160000-trained_model-17-16_12.pth
# 3      60   /230000-trained_model-13-12_37.pth
# 1      30   /130000-trained_model-17-00_44.pth
# 23     27  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10     72   /130000-trained_model-13-09_42.pth
# 14     63   /160000-trained_model-17-16_12.pth
# 3      60   /230000-trained_model-13-12_37.pth
# 1      30   /130000-trained_model-17-00_44.pth
# 23     27  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10     75   /130000-trained_model-13-09_42.pth
# 14     63   /160000-trained_model-17-16_12.pth
# 3      60   /230000-trained_model-13-12_37.pth
# 23     30  /1670000-trained_model-17-00_11.pth
# 1      30   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10     75   /130000-trained_model-13-09_42.pth
# 14     63   /160000-trained_model-17-16_12.pth
# 3      63   /230000-trained_model-13-12_37.pth
# 23     36  /1670000-trained_model-17-00_11.pth
# 1      33   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10     81   /130000-trained_model-13-09_42.pth
# 14     78   /160000-trained_model-17-16_12.pth
# 3      75   /230000-trained_model-13-12_37.pth
# 23     45  /1670000-trained_model-17-00_11.pth
# 1      45   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10    117   /130000-trained_model-13-09_42.pth
# 3      93   /230000-trained_model-13-12_37.pth
# 14     84   /160000-trained_model-17-16_12.pth
# 23     60  /1670000-trained_model-17-00_11.pth
# 1      57   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10    129   /130000-trained_model-13-09_42.pth
# 3      99   /230000-trained_model-13-12_37.pth
# 14     90   /160000-trained_model-17-16_12.pth
# 23     60  /1670000-trained_model-17-00_11.pth
# 1      60   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10    138   /130000-trained_model-13-09_42.pth
# 3     105   /230000-trained_model-13-12_37.pth
# 14    102   /160000-trained_model-17-16_12.pth
# 23     60  /1670000-trained_model-17-00_11.pth
# 1      60   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10    144   /130000-trained_model-13-09_42.pth
# 3     105   /230000-trained_model-13-12_37.pth
# 14    105   /160000-trained_model-17-16_12.pth
# 1      63   /130000-trained_model-17-00_44.pth
# 23     57  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    144   /130000-trained_model-13-09_42.pth
# 3     117   /230000-trained_model-13-12_37.pth
# 14    105   /160000-trained_model-17-16_12.pth
# 1      66   /130000-trained_model-17-00_44.pth
# 23     60  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    144   /130000-trained_model-13-09_42.pth
# 3     117   /230000-trained_model-13-12_37.pth
# 14    111   /160000-trained_model-17-16_12.pth
# 23     69  /1670000-trained_model-17-00_11.pth
# 1      69   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10    147   /130000-trained_model-13-09_42.pth
# 3     120   /230000-trained_model-13-12_37.pth
# 14    111   /160000-trained_model-17-16_12.pth
# 23     69  /1670000-trained_model-17-00_11.pth
# 1      69   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10    156   /130000-trained_model-13-09_42.pth
# 3     129   /230000-trained_model-13-12_37.pth
# 14    117   /160000-trained_model-17-16_12.pth
# 23     72  /1670000-trained_model-17-00_11.pth
# 1      72   /130000-trained_model-17-00_44.pth
#     score                            name_sort
# 10    156   /130000-trained_model-13-09_42.pth
# 3     129   /230000-trained_model-13-12_37.pth
# 14    117   /160000-trained_model-17-16_12.pth
# 1      75   /130000-trained_model-17-00_44.pth
# 23     72  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    174   /130000-trained_model-13-09_42.pth
# 3     138   /230000-trained_model-13-12_37.pth
# 14    132   /160000-trained_model-17-16_12.pth
# 1      87   /130000-trained_model-17-00_44.pth
# 23     81  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    171   /130000-trained_model-13-09_42.pth
# 14    138   /160000-trained_model-17-16_12.pth
# 3     135   /230000-trained_model-13-12_37.pth
# 1      93   /130000-trained_model-17-00_44.pth
# 23     81  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    195   /130000-trained_model-13-09_42.pth
# 14    159   /160000-trained_model-17-16_12.pth
# 3     141   /230000-trained_model-13-12_37.pth
# 1     129   /130000-trained_model-17-00_44.pth
# 23     87  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    201   /130000-trained_model-13-09_42.pth
# 14    174   /160000-trained_model-17-16_12.pth
# 1     156   /130000-trained_model-17-00_44.pth
# 3     147   /230000-trained_model-13-12_37.pth
# 23    111  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    201   /130000-trained_model-13-09_42.pth
# 14    174   /160000-trained_model-17-16_12.pth
# 1     156   /130000-trained_model-17-00_44.pth
# 3     153   /230000-trained_model-13-12_37.pth
# 23    111  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    210   /130000-trained_model-13-09_42.pth
# 14    189   /160000-trained_model-17-16_12.pth
# 3     168   /230000-trained_model-13-12_37.pth
# 1     156   /130000-trained_model-17-00_44.pth
# 23    105  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    225   /130000-trained_model-13-09_42.pth
# 14    198   /160000-trained_model-17-16_12.pth
# 3     174   /230000-trained_model-13-12_37.pth
# 1     162   /130000-trained_model-17-00_44.pth
# 23     99  /1670000-trained_model-17-00_11.pth
#     score                            name_sort
# 10    225   /130000-trained_model-13-09_42.pth
# 14    198   /160000-trained_model-17-16_12.pth
# 3     174   /230000-trained_model-13-12_37.pth
# 1     162   /130000-trained_model-17-00_44.pth
# 23    102  /1670000-trained_model-17-00_11.pth
#     score                           name_sort
# 10    231  /130000-trained_model-13-09_42.pth
# 14    201  /160000-trained_model-17-16_12.pth
# 3     171  /230000-trained_model-13-12_37.pth
# 1     168  /130000-trained_model-17-00_44.pth
# 5      96  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    243  /130000-trained_model-13-09_42.pth
# 14    225  /160000-trained_model-17-16_12.pth
# 1     192  /130000-trained_model-17-00_44.pth
# 3     177  /230000-trained_model-13-12_37.pth
# 5     108  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    246  /130000-trained_model-13-09_42.pth
# 14    225  /160000-trained_model-17-16_12.pth
# 1     192  /130000-trained_model-17-00_44.pth
# 3     189  /230000-trained_model-13-12_37.pth
# 5     108  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    246  /130000-trained_model-13-09_42.pth
# 14    225  /160000-trained_model-17-16_12.pth
# 1     204  /130000-trained_model-17-00_44.pth
# 3     195  /230000-trained_model-13-12_37.pth
# 5     114  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    249  /130000-trained_model-13-09_42.pth
# 14    234  /160000-trained_model-17-16_12.pth
# 1     207  /130000-trained_model-17-00_44.pth
# 3     201  /230000-trained_model-13-12_37.pth
# 5     132  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    258  /130000-trained_model-13-09_42.pth
# 14    231  /160000-trained_model-17-16_12.pth
# 1     219  /130000-trained_model-17-00_44.pth
# 3     207  /230000-trained_model-13-12_37.pth
# 5     138  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    282  /130000-trained_model-13-09_42.pth
# 14    237  /160000-trained_model-17-16_12.pth
# 3     222  /230000-trained_model-13-12_37.pth
# 1     222  /130000-trained_model-17-00_44.pth
# 5     138  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    285  /130000-trained_model-13-09_42.pth
# 14    237  /160000-trained_model-17-16_12.pth
# 3     228  /230000-trained_model-13-12_37.pth
# 1     222  /130000-trained_model-17-00_44.pth
# 5     138  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    285  /130000-trained_model-13-09_42.pth
# 14    237  /160000-trained_model-17-16_12.pth
# 3     234  /230000-trained_model-13-12_37.pth
# 1     222  /130000-trained_model-17-00_44.pth
# 5     144  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    288  /130000-trained_model-13-09_42.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 14    237  /160000-trained_model-17-16_12.pth
# 1     225  /130000-trained_model-17-00_44.pth
# 5     153  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    291  /130000-trained_model-13-09_42.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 14    240  /160000-trained_model-17-16_12.pth
# 1     222  /130000-trained_model-17-00_44.pth
# 5     153  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    291  /130000-trained_model-13-09_42.pth
# 14    246  /160000-trained_model-17-16_12.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 1     231  /130000-trained_model-17-00_44.pth
# 5     150  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    291  /130000-trained_model-13-09_42.pth
# 14    246  /160000-trained_model-17-16_12.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 1     234  /130000-trained_model-17-00_44.pth
# 5     153  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    291  /130000-trained_model-13-09_42.pth
# 14    246  /160000-trained_model-17-16_12.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 1     234  /130000-trained_model-17-00_44.pth
# 5     150  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    294  /130000-trained_model-13-09_42.pth
# 14    246  /160000-trained_model-17-16_12.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 1     240  /130000-trained_model-17-00_44.pth
# 5     150  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    309  /130000-trained_model-13-09_42.pth
# 14    249  /160000-trained_model-17-16_12.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 1     237  /130000-trained_model-17-00_44.pth
# 5     162  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    309  /130000-trained_model-13-09_42.pth
# 14    252  /160000-trained_model-17-16_12.pth
# 3     243  /230000-trained_model-13-12_37.pth
# 1     237  /130000-trained_model-17-00_44.pth
# 5     162  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    318  /130000-trained_model-13-09_42.pth
# 14    273  /160000-trained_model-17-16_12.pth
# 1     264  /130000-trained_model-17-00_44.pth
# 3     246  /230000-trained_model-13-12_37.pth
# 5     168  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    327  /130000-trained_model-13-09_42.pth
# 1     270  /130000-trained_model-17-00_44.pth
# 14    267  /160000-trained_model-17-16_12.pth
# 3     246  /230000-trained_model-13-12_37.pth
# 5     171  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    360  /130000-trained_model-13-09_42.pth
# 1     291  /130000-trained_model-17-00_44.pth
# 14    282  /160000-trained_model-17-16_12.pth
# 3     258  /230000-trained_model-13-12_37.pth
# 5     177  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    363  /130000-trained_model-13-09_42.pth
# 1     294  /130000-trained_model-17-00_44.pth
# 14    288  /160000-trained_model-17-16_12.pth
# 3     267  /230000-trained_model-13-12_37.pth
# 5     177  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    369  /130000-trained_model-13-09_42.pth
# 14    294  /160000-trained_model-17-16_12.pth
# 1     294  /130000-trained_model-17-00_44.pth
# 3     282  /230000-trained_model-13-12_37.pth
# 5     183  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    378  /130000-trained_model-13-09_42.pth
# 14    303  /160000-trained_model-17-16_12.pth
# 1     300  /130000-trained_model-17-00_44.pth
# 3     291  /230000-trained_model-13-12_37.pth
# 5     183  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    387  /130000-trained_model-13-09_42.pth
# 14    315  /160000-trained_model-17-16_12.pth
# 1     312  /130000-trained_model-17-00_44.pth
# 3     288  /230000-trained_model-13-12_37.pth
# 5     180  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    387  /130000-trained_model-13-09_42.pth
# 14    318  /160000-trained_model-17-16_12.pth
# 1     312  /130000-trained_model-17-00_44.pth
# 3     288  /230000-trained_model-13-12_37.pth
# 5     177  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    393  /130000-trained_model-13-09_42.pth
# 1     333  /130000-trained_model-17-00_44.pth
# 14    324  /160000-trained_model-17-16_12.pth
# 3     282  /230000-trained_model-13-12_37.pth
# 5     186  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    393  /130000-trained_model-13-09_42.pth
# 1     336  /130000-trained_model-17-00_44.pth
# 14    324  /160000-trained_model-17-16_12.pth
# 3     279  /230000-trained_model-13-12_37.pth
# 0     183  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    396  /130000-trained_model-13-09_42.pth
# 1     339  /130000-trained_model-17-00_44.pth
# 14    327  /160000-trained_model-17-16_12.pth
# 3     279  /230000-trained_model-13-12_37.pth
# 5     189  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    396  /130000-trained_model-13-09_42.pth
# 1     339  /130000-trained_model-17-00_44.pth
# 14    327  /160000-trained_model-17-16_12.pth
# 3     276  /230000-trained_model-13-12_37.pth
# 0     189  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    399  /130000-trained_model-13-09_42.pth
# 1     348  /130000-trained_model-17-00_44.pth
# 14    333  /160000-trained_model-17-16_12.pth
# 3     279  /230000-trained_model-13-12_37.pth
# 5     186  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    402  /130000-trained_model-13-09_42.pth
# 1     342  /130000-trained_model-17-00_44.pth
# 14    339  /160000-trained_model-17-16_12.pth
# 3     282  /230000-trained_model-13-12_37.pth
# 5     198  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    432  /130000-trained_model-13-09_42.pth
# 1     369  /130000-trained_model-17-00_44.pth
# 14    357  /160000-trained_model-17-16_12.pth
# 3     285  /230000-trained_model-13-12_37.pth
# 5     204  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    435  /130000-trained_model-13-09_42.pth
# 1     378  /130000-trained_model-17-00_44.pth
# 14    354  /160000-trained_model-17-16_12.pth
# 3     291  /230000-trained_model-13-12_37.pth
# 5     204  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    444  /130000-trained_model-13-09_42.pth
# 1     381  /130000-trained_model-17-00_44.pth
# 14    354  /160000-trained_model-17-16_12.pth
# 3     291  /230000-trained_model-13-12_37.pth
# 5     210  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    444  /130000-trained_model-13-09_42.pth
# 1     384  /130000-trained_model-17-00_44.pth
# 14    360  /160000-trained_model-17-16_12.pth
# 3     291  /230000-trained_model-13-12_37.pth
# 5     210  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    444  /130000-trained_model-13-09_42.pth
# 1     387  /130000-trained_model-17-00_44.pth
# 14    363  /160000-trained_model-17-16_12.pth
# 3     291  /230000-trained_model-13-12_37.pth
# 5     207  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    450  /130000-trained_model-13-09_42.pth
# 1     393  /130000-trained_model-17-00_44.pth
# 14    369  /160000-trained_model-17-16_12.pth
# 3     291  /230000-trained_model-13-12_37.pth
# 5     204  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    453  /130000-trained_model-13-09_42.pth
# 1     396  /130000-trained_model-17-00_44.pth
# 14    372  /160000-trained_model-17-16_12.pth
# 3     291  /230000-trained_model-13-12_37.pth
# 5     204  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    465  /130000-trained_model-13-09_42.pth
# 1     402  /130000-trained_model-17-00_44.pth
# 14    381  /160000-trained_model-17-16_12.pth
# 3     303  /230000-trained_model-13-12_37.pth
# 5     201  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    468  /130000-trained_model-13-09_42.pth
# 1     402  /130000-trained_model-17-00_44.pth
# 14    387  /160000-trained_model-17-16_12.pth
# 3     303  /230000-trained_model-13-12_37.pth
# 5     210  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    477  /130000-trained_model-13-09_42.pth
# 1     408  /130000-trained_model-17-00_44.pth
# 14    393  /160000-trained_model-17-16_12.pth
# 3     309  /230000-trained_model-13-12_37.pth
# 5     210  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    495  /130000-trained_model-13-09_42.pth
# 1     414  /130000-trained_model-17-00_44.pth
# 14    402  /160000-trained_model-17-16_12.pth
# 3     312  /230000-trained_model-13-12_37.pth
# 5     222  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    504  /130000-trained_model-13-09_42.pth
# 14    414  /160000-trained_model-17-16_12.pth
# 1     411  /130000-trained_model-17-00_44.pth
# 3     318  /230000-trained_model-13-12_37.pth
# 5     222  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    510  /130000-trained_model-13-09_42.pth
# 14    426  /160000-trained_model-17-16_12.pth
# 1     414  /130000-trained_model-17-00_44.pth
# 3     321  /230000-trained_model-13-12_37.pth
# 5     222  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    513  /130000-trained_model-13-09_42.pth
# 14    429  /160000-trained_model-17-16_12.pth
# 1     417  /130000-trained_model-17-00_44.pth
# 3     321  /230000-trained_model-13-12_37.pth
# 5     219  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    513  /130000-trained_model-13-09_42.pth
# 14    429  /160000-trained_model-17-16_12.pth
# 1     414  /130000-trained_model-17-00_44.pth
# 3     324  /230000-trained_model-13-12_37.pth
# 5     219  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    534  /130000-trained_model-13-09_42.pth
# 14    426  /160000-trained_model-17-16_12.pth
# 1     414  /130000-trained_model-17-00_44.pth
# 3     327  /230000-trained_model-13-12_37.pth
# 5     225  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    534  /130000-trained_model-13-09_42.pth
# 14    423  /160000-trained_model-17-16_12.pth
# 1     417  /130000-trained_model-17-00_44.pth
# 3     339  /230000-trained_model-13-12_37.pth
# 5     237  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    546  /130000-trained_model-13-09_42.pth
# 1     429  /130000-trained_model-17-00_44.pth
# 14    426  /160000-trained_model-17-16_12.pth
# 3     339  /230000-trained_model-13-12_37.pth
# 5     243  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    552  /130000-trained_model-13-09_42.pth
# 1     429  /130000-trained_model-17-00_44.pth
# 14    429  /160000-trained_model-17-16_12.pth
# 3     339  /230000-trained_model-13-12_37.pth
# 5     246  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    552  /130000-trained_model-13-09_42.pth
# 1     429  /130000-trained_model-17-00_44.pth
# 14    429  /160000-trained_model-17-16_12.pth
# 3     339  /230000-trained_model-13-12_37.pth
# 5     246  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    561  /130000-trained_model-13-09_42.pth
# 14    432  /160000-trained_model-17-16_12.pth
# 1     432  /130000-trained_model-17-00_44.pth
# 3     342  /230000-trained_model-13-12_37.pth
# 5     249  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    564  /130000-trained_model-13-09_42.pth
# 14    432  /160000-trained_model-17-16_12.pth
# 1     432  /130000-trained_model-17-00_44.pth
# 3     342  /230000-trained_model-13-12_37.pth
# 5     249  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    579  /130000-trained_model-13-09_42.pth
# 1     435  /130000-trained_model-17-00_44.pth
# 14    432  /160000-trained_model-17-16_12.pth
# 3     342  /230000-trained_model-13-12_37.pth
# 5     252  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    579  /130000-trained_model-13-09_42.pth
# 1     435  /130000-trained_model-17-00_44.pth
# 14    432  /160000-trained_model-17-16_12.pth
# 3     345  /230000-trained_model-13-12_37.pth
# 5     252  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    579  /130000-trained_model-13-09_42.pth
# 14    450  /160000-trained_model-17-16_12.pth
# 1     444  /130000-trained_model-17-00_44.pth
# 3     354  /230000-trained_model-13-12_37.pth
# 5     255  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    582  /130000-trained_model-13-09_42.pth
# 14    453  /160000-trained_model-17-16_12.pth
# 1     444  /130000-trained_model-17-00_44.pth
# 3     354  /230000-trained_model-13-12_37.pth
# 5     255  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    582  /130000-trained_model-13-09_42.pth
# 14    453  /160000-trained_model-17-16_12.pth
# 1     444  /130000-trained_model-17-00_44.pth
# 3     354  /230000-trained_model-13-12_37.pth
# 5     255  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    588  /130000-trained_model-13-09_42.pth
# 14    456  /160000-trained_model-17-16_12.pth
# 1     450  /130000-trained_model-17-00_44.pth
# 3     366  /230000-trained_model-13-12_37.pth
# 5     261  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    597  /130000-trained_model-13-09_42.pth
# 14    480  /160000-trained_model-17-16_12.pth
# 1     471  /130000-trained_model-17-00_44.pth
# 3     384  /230000-trained_model-13-12_37.pth
# 5     273  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    597  /130000-trained_model-13-09_42.pth
# 14    483  /160000-trained_model-17-16_12.pth
# 1     471  /130000-trained_model-17-00_44.pth
# 3     396  /230000-trained_model-13-12_37.pth
# 5     279  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    612  /130000-trained_model-13-09_42.pth
# 1     492  /130000-trained_model-17-00_44.pth
# 14    483  /160000-trained_model-17-16_12.pth
# 3     417  /230000-trained_model-13-12_37.pth
# 5     291  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    618  /130000-trained_model-13-09_42.pth
# 14    492  /160000-trained_model-17-16_12.pth
# 1     486  /130000-trained_model-17-00_44.pth
# 3     426  /230000-trained_model-13-12_37.pth
# 5     294  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    621  /130000-trained_model-13-09_42.pth
# 14    495  /160000-trained_model-17-16_12.pth
# 1     483  /130000-trained_model-17-00_44.pth
# 3     426  /230000-trained_model-13-12_37.pth
# 5     309  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    645  /130000-trained_model-13-09_42.pth
# 14    507  /160000-trained_model-17-16_12.pth
# 1     507  /130000-trained_model-17-00_44.pth
# 3     429  /230000-trained_model-13-12_37.pth
# 5     303  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    651  /130000-trained_model-13-09_42.pth
# 14    507  /160000-trained_model-17-16_12.pth
# 1     507  /130000-trained_model-17-00_44.pth
# 3     432  /230000-trained_model-13-12_37.pth
# 5     300  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    651  /130000-trained_model-13-09_42.pth
# 14    507  /160000-trained_model-17-16_12.pth
# 1     507  /130000-trained_model-17-00_44.pth
# 3     432  /230000-trained_model-13-12_37.pth
# 5     300  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    657  /130000-trained_model-13-09_42.pth
# 14    519  /160000-trained_model-17-16_12.pth
# 1     513  /130000-trained_model-17-00_44.pth
# 3     435  /230000-trained_model-13-12_37.pth
# 5     309  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    666  /130000-trained_model-13-09_42.pth
# 14    525  /160000-trained_model-17-16_12.pth
# 1     513  /130000-trained_model-17-00_44.pth
# 3     429  /230000-trained_model-13-12_37.pth
# 5     312  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    666  /130000-trained_model-13-09_42.pth
# 14    522  /160000-trained_model-17-16_12.pth
# 1     513  /130000-trained_model-17-00_44.pth
# 3     429  /230000-trained_model-13-12_37.pth
# 5     312  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    678  /130000-trained_model-13-09_42.pth
# 1     531  /130000-trained_model-17-00_44.pth
# 14    528  /160000-trained_model-17-16_12.pth
# 3     444  /230000-trained_model-13-12_37.pth
# 5     306  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    687  /130000-trained_model-13-09_42.pth
# 14    540  /160000-trained_model-17-16_12.pth
# 1     534  /130000-trained_model-17-00_44.pth
# 3     447  /230000-trained_model-13-12_37.pth
# 5     303  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    687  /130000-trained_model-13-09_42.pth
# 14    552  /160000-trained_model-17-16_12.pth
# 1     537  /130000-trained_model-17-00_44.pth
# 3     453  /230000-trained_model-13-12_37.pth
# 5     303  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    696  /130000-trained_model-13-09_42.pth
# 14    555  /160000-trained_model-17-16_12.pth
# 1     549  /130000-trained_model-17-00_44.pth
# 3     456  /230000-trained_model-13-12_37.pth
# 5     303  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    702  /130000-trained_model-13-09_42.pth
# 14    561  /160000-trained_model-17-16_12.pth
# 1     549  /130000-trained_model-17-00_44.pth
# 3     468  /230000-trained_model-13-12_37.pth
# 5     306  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    702  /130000-trained_model-13-09_42.pth
# 14    561  /160000-trained_model-17-16_12.pth
# 1     549  /130000-trained_model-17-00_44.pth
# 3     468  /230000-trained_model-13-12_37.pth
# 5     306  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    717  /130000-trained_model-13-09_42.pth
# 14    579  /160000-trained_model-17-16_12.pth
# 1     558  /130000-trained_model-17-00_44.pth
# 3     486  /230000-trained_model-13-12_37.pth
# 5     318  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    717  /130000-trained_model-13-09_42.pth
# 14    585  /160000-trained_model-17-16_12.pth
# 1     561  /130000-trained_model-17-00_44.pth
# 3     486  /230000-trained_model-13-12_37.pth
# 5     336  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    720  /130000-trained_model-13-09_42.pth
# 14    597  /160000-trained_model-17-16_12.pth
# 1     573  /130000-trained_model-17-00_44.pth
# 3     492  /230000-trained_model-13-12_37.pth
# 5     339  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    723  /130000-trained_model-13-09_42.pth
# 14    600  /160000-trained_model-17-16_12.pth
# 1     573  /130000-trained_model-17-00_44.pth
# 3     492  /230000-trained_model-13-12_37.pth
# 5     339  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    726  /130000-trained_model-13-09_42.pth
# 14    600  /160000-trained_model-17-16_12.pth
# 1     582  /130000-trained_model-17-00_44.pth
# 3     498  /230000-trained_model-13-12_37.pth
# 5     336  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    723  /130000-trained_model-13-09_42.pth
# 14    603  /160000-trained_model-17-16_12.pth
# 1     585  /130000-trained_model-17-00_44.pth
# 3     498  /230000-trained_model-13-12_37.pth
# 5     342  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    726  /130000-trained_model-13-09_42.pth
# 14    603  /160000-trained_model-17-16_12.pth
# 1     588  /130000-trained_model-17-00_44.pth
# 3     498  /230000-trained_model-13-12_37.pth
# 5     342  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    735  /130000-trained_model-13-09_42.pth
# 14    618  /160000-trained_model-17-16_12.pth
# 1     591  /130000-trained_model-17-00_44.pth
# 3     495  /230000-trained_model-13-12_37.pth
# 5     342  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    735  /130000-trained_model-13-09_42.pth
# 14    621  /160000-trained_model-17-16_12.pth
# 1     594  /130000-trained_model-17-00_44.pth
# 3     498  /230000-trained_model-13-12_37.pth
# 5     342  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    741  /130000-trained_model-13-09_42.pth
# 14    660  /160000-trained_model-17-16_12.pth
# 1     612  /130000-trained_model-17-00_44.pth
# 3     513  /230000-trained_model-13-12_37.pth
# 5     336  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    750  /130000-trained_model-13-09_42.pth
# 14    663  /160000-trained_model-17-16_12.pth
# 1     612  /130000-trained_model-17-00_44.pth
# 3     513  /230000-trained_model-13-12_37.pth
# 5     342  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    753  /130000-trained_model-13-09_42.pth
# 14    675  /160000-trained_model-17-16_12.pth
# 1     618  /130000-trained_model-17-00_44.pth
# 3     513  /230000-trained_model-13-12_37.pth
# 5     351  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    768  /130000-trained_model-13-09_42.pth
# 14    681  /160000-trained_model-17-16_12.pth
# 1     630  /130000-trained_model-17-00_44.pth
# 3     522  /230000-trained_model-13-12_37.pth
# 5     351  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    771  /130000-trained_model-13-09_42.pth
# 14    681  /160000-trained_model-17-16_12.pth
# 1     630  /130000-trained_model-17-00_44.pth
# 3     522  /230000-trained_model-13-12_37.pth
# 5     351  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    774  /130000-trained_model-13-09_42.pth
# 14    693  /160000-trained_model-17-16_12.pth
# 1     633  /130000-trained_model-17-00_44.pth
# 3     525  /230000-trained_model-13-12_37.pth
# 5     357  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    774  /130000-trained_model-13-09_42.pth
# 14    696  /160000-trained_model-17-16_12.pth
# 1     633  /130000-trained_model-17-00_44.pth
# 3     525  /230000-trained_model-13-12_37.pth
# 5     357  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    798  /130000-trained_model-13-09_42.pth
# 14    717  /160000-trained_model-17-16_12.pth
# 1     654  /130000-trained_model-17-00_44.pth
# 3     546  /230000-trained_model-13-12_37.pth
# 12    369  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    798  /130000-trained_model-13-09_42.pth
# 14    720  /160000-trained_model-17-16_12.pth
# 1     654  /130000-trained_model-17-00_44.pth
# 3     546  /230000-trained_model-13-12_37.pth
# 12    372  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    801  /130000-trained_model-13-09_42.pth
# 14    720  /160000-trained_model-17-16_12.pth
# 1     654  /130000-trained_model-17-00_44.pth
# 3     549  /230000-trained_model-13-12_37.pth
# 12    375  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    801  /130000-trained_model-13-09_42.pth
# 14    720  /160000-trained_model-17-16_12.pth
# 1     654  /130000-trained_model-17-00_44.pth
# 3     549  /230000-trained_model-13-12_37.pth
# 12    378  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    804  /130000-trained_model-13-09_42.pth
# 14    723  /160000-trained_model-17-16_12.pth
# 1     657  /130000-trained_model-17-00_44.pth
# 3     549  /230000-trained_model-13-12_37.pth
# 12    375  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    816  /130000-trained_model-13-09_42.pth
# 14    726  /160000-trained_model-17-16_12.pth
# 1     657  /130000-trained_model-17-00_44.pth
# 3     546  /230000-trained_model-13-12_37.pth
# 12    375  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    816  /130000-trained_model-13-09_42.pth
# 14    729  /160000-trained_model-17-16_12.pth
# 1     657  /130000-trained_model-17-00_44.pth
# 3     543  /230000-trained_model-13-12_37.pth
# 12    384  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    825  /130000-trained_model-13-09_42.pth
# 14    732  /160000-trained_model-17-16_12.pth
# 1     657  /130000-trained_model-17-00_44.pth
# 3     543  /230000-trained_model-13-12_37.pth
# 12    381  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    825  /130000-trained_model-13-09_42.pth
# 14    729  /160000-trained_model-17-16_12.pth
# 1     669  /130000-trained_model-17-00_44.pth
# 3     552  /230000-trained_model-13-12_37.pth
# 5     381  /140000-trained_model-17-15_07.pth
#     score                           name_sort
# 10    831  /130000-trained_model-13-09_42.pth
# 14    732  /160000-trained_model-17-16_12.pth
# 1     675  /130000-trained_model-17-00_44.pth
# 3     561  /230000-trained_model-13-12_37.pth
# 12    381  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    831  /130000-trained_model-13-09_42.pth
# 14    732  /160000-trained_model-17-16_12.pth
# 1     675  /130000-trained_model-17-00_44.pth
# 3     561  /230000-trained_model-13-12_37.pth
# 12    384  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    831  /130000-trained_model-13-09_42.pth
# 14    735  /160000-trained_model-17-16_12.pth
# 1     678  /130000-trained_model-17-00_44.pth
# 3     561  /230000-trained_model-13-12_37.pth
# 12    384  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    834  /130000-trained_model-13-09_42.pth
# 14    735  /160000-trained_model-17-16_12.pth
# 1     678  /130000-trained_model-17-00_44.pth
# 3     561  /230000-trained_model-13-12_37.pth
# 12    381  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    831  /130000-trained_model-13-09_42.pth
# 14    744  /160000-trained_model-17-16_12.pth
# 1     678  /130000-trained_model-17-00_44.pth
# 3     567  /230000-trained_model-13-12_37.pth
# 0     381  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    849  /130000-trained_model-13-09_42.pth
# 14    756  /160000-trained_model-17-16_12.pth
# 1     678  /130000-trained_model-17-00_44.pth
# 3     570  /230000-trained_model-13-12_37.pth
# 12    387  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    852  /130000-trained_model-13-09_42.pth
# 14    756  /160000-trained_model-17-16_12.pth
# 1     690  /130000-trained_model-17-00_44.pth
# 3     576  /230000-trained_model-13-12_37.pth
# 12    393  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    852  /130000-trained_model-13-09_42.pth
# 14    768  /160000-trained_model-17-16_12.pth
# 1     693  /130000-trained_model-17-00_44.pth
# 3     576  /230000-trained_model-13-12_37.pth
# 12    393  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    855  /130000-trained_model-13-09_42.pth
# 14    768  /160000-trained_model-17-16_12.pth
# 1     696  /130000-trained_model-17-00_44.pth
# 3     585  /230000-trained_model-13-12_37.pth
# 12    396  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    852  /130000-trained_model-13-09_42.pth
# 14    774  /160000-trained_model-17-16_12.pth
# 1     696  /130000-trained_model-17-00_44.pth
# 3     585  /230000-trained_model-13-12_37.pth
# 12    399  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    852  /130000-trained_model-13-09_42.pth
# 14    777  /160000-trained_model-17-16_12.pth
# 1     711  /130000-trained_model-17-00_44.pth
# 3     591  /230000-trained_model-13-12_37.pth
# 12    396  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    855  /130000-trained_model-13-09_42.pth
# 14    780  /160000-trained_model-17-16_12.pth
# 1     711  /130000-trained_model-17-00_44.pth
# 3     591  /230000-trained_model-13-12_37.pth
# 12    396  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    858  /130000-trained_model-13-09_42.pth
# 14    792  /160000-trained_model-17-16_12.pth
# 1     711  /130000-trained_model-17-00_44.pth
# 3     600  /230000-trained_model-13-12_37.pth
# 12    408  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    864  /130000-trained_model-13-09_42.pth
# 14    801  /160000-trained_model-17-16_12.pth
# 1     717  /130000-trained_model-17-00_44.pth
# 3     615  /230000-trained_model-13-12_37.pth
# 12    408  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    864  /130000-trained_model-13-09_42.pth
# 14    804  /160000-trained_model-17-16_12.pth
# 1     720  /130000-trained_model-17-00_44.pth
# 3     618  /230000-trained_model-13-12_37.pth
# 12    411  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    867  /130000-trained_model-13-09_42.pth
# 14    807  /160000-trained_model-17-16_12.pth
# 1     723  /130000-trained_model-17-00_44.pth
# 3     618  /230000-trained_model-13-12_37.pth
# 12    420  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    867  /130000-trained_model-13-09_42.pth
# 14    810  /160000-trained_model-17-16_12.pth
# 1     723  /130000-trained_model-17-00_44.pth
# 3     615  /230000-trained_model-13-12_37.pth
# 12    420  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    873  /130000-trained_model-13-09_42.pth
# 14    816  /160000-trained_model-17-16_12.pth
# 1     726  /130000-trained_model-17-00_44.pth
# 3     615  /230000-trained_model-13-12_37.pth
# 12    420  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    897  /130000-trained_model-13-09_42.pth
# 14    825  /160000-trained_model-17-16_12.pth
# 1     735  /130000-trained_model-17-00_44.pth
# 3     624  /230000-trained_model-13-12_37.pth
# 12    420  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    900  /130000-trained_model-13-09_42.pth
# 14    825  /160000-trained_model-17-16_12.pth
# 1     735  /130000-trained_model-17-00_44.pth
# 3     624  /230000-trained_model-13-12_37.pth
# 12    417  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    900  /130000-trained_model-13-09_42.pth
# 14    831  /160000-trained_model-17-16_12.pth
# 1     741  /130000-trained_model-17-00_44.pth
# 3     624  /230000-trained_model-13-12_37.pth
# 12    420  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    903  /130000-trained_model-13-09_42.pth
# 14    840  /160000-trained_model-17-16_12.pth
# 1     741  /130000-trained_model-17-00_44.pth
# 3     624  /230000-trained_model-13-12_37.pth
# 12    417  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    897  /130000-trained_model-13-09_42.pth
# 14    843  /160000-trained_model-17-16_12.pth
# 1     744  /130000-trained_model-17-00_44.pth
# 3     642  /230000-trained_model-13-12_37.pth
# 12    429  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    906  /130000-trained_model-13-09_42.pth
# 14    852  /160000-trained_model-17-16_12.pth
# 1     756  /130000-trained_model-17-00_44.pth
# 3     660  /230000-trained_model-13-12_37.pth
# 12    435  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    906  /130000-trained_model-13-09_42.pth
# 14    855  /160000-trained_model-17-16_12.pth
# 1     759  /130000-trained_model-17-00_44.pth
# 3     663  /230000-trained_model-13-12_37.pth
# 12    444  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    915  /130000-trained_model-13-09_42.pth
# 14    861  /160000-trained_model-17-16_12.pth
# 1     762  /130000-trained_model-17-00_44.pth
# 3     669  /230000-trained_model-13-12_37.pth
# 12    447  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    933  /130000-trained_model-13-09_42.pth
# 14    873  /160000-trained_model-17-16_12.pth
# 1     768  /130000-trained_model-17-00_44.pth
# 3     675  /230000-trained_model-13-12_37.pth
# 12    447  /530000-trained_model-13-21_08.pth
#     score                           name_sort
# 10    954  /130000-trained_model-13-09_42.pth
# 14    885  /160000-trained_model-17-16_12.pth
# 1     786  /130000-trained_model-17-00_44.pth
# 3     699  /230000-trained_model-13-12_37.pth
# 0     450  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    963  /130000-trained_model-13-09_42.pth
# 14    882  /160000-trained_model-17-16_12.pth
# 1     798  /130000-trained_model-17-00_44.pth
# 3     693  /230000-trained_model-13-12_37.pth
# 0     456  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    963  /130000-trained_model-13-09_42.pth
# 14    888  /160000-trained_model-17-16_12.pth
# 1     801  /130000-trained_model-17-00_44.pth
# 3     693  /230000-trained_model-13-12_37.pth
# 0     459  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    966  /130000-trained_model-13-09_42.pth
# 14    906  /160000-trained_model-17-16_12.pth
# 1     801  /130000-trained_model-17-00_44.pth
# 3     693  /230000-trained_model-13-12_37.pth
# 0     462  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    978  /130000-trained_model-13-09_42.pth
# 14    915  /160000-trained_model-17-16_12.pth
# 1     810  /130000-trained_model-17-00_44.pth
# 3     693  /230000-trained_model-13-12_37.pth
# 0     477  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    981  /130000-trained_model-13-09_42.pth
# 14    921  /160000-trained_model-17-16_12.pth
# 1     819  /130000-trained_model-17-00_44.pth
# 3     693  /230000-trained_model-13-12_37.pth
# 0     480  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10    981  /130000-trained_model-13-09_42.pth
# 14    924  /160000-trained_model-17-16_12.pth
# 1     819  /130000-trained_model-17-00_44.pth
# 3     696  /230000-trained_model-13-12_37.pth
# 0     486  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1008  /130000-trained_model-13-09_42.pth
# 14    933  /160000-trained_model-17-16_12.pth
# 1     825  /130000-trained_model-17-00_44.pth
# 3     705  /230000-trained_model-13-12_37.pth
# 0     489  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1008  /130000-trained_model-13-09_42.pth
# 14    948  /160000-trained_model-17-16_12.pth
# 1     825  /130000-trained_model-17-00_44.pth
# 3     705  /230000-trained_model-13-12_37.pth
# 0     492  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1023  /130000-trained_model-13-09_42.pth
# 14    972  /160000-trained_model-17-16_12.pth
# 1     828  /130000-trained_model-17-00_44.pth
# 3     717  /230000-trained_model-13-12_37.pth
# 0     501  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1029  /130000-trained_model-13-09_42.pth
# 14    972  /160000-trained_model-17-16_12.pth
# 1     834  /130000-trained_model-17-00_44.pth
# 3     717  /230000-trained_model-13-12_37.pth
# 0     501  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1041  /130000-trained_model-13-09_42.pth
# 14    990  /160000-trained_model-17-16_12.pth
# 1     837  /130000-trained_model-17-00_44.pth
# 3     726  /230000-trained_model-13-12_37.pth
# 0     504  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1047  /130000-trained_model-13-09_42.pth
# ...
# 10   1302  /130000-trained_model-13-09_42.pth
# 14   1209  /160000-trained_model-17-16_12.pth
# 1    1044  /130000-trained_model-17-00_44.pth
# 3     921  /230000-trained_model-13-12_37.pth
# 0     633  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1308  /130000-trained_model-13-09_42.pth
# 14   1212  /160000-trained_model-17-16_12.pth
# 1    1050  /130000-trained_model-17-00_44.pth
# 3     921  /230000-trained_model-13-12_37.pth
# 0     630  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1308  /130000-trained_model-13-09_42.pth
# 14   1209  /160000-trained_model-17-16_12.pth
# 1    1050  /130000-trained_model-17-00_44.pth
# 3     921  /230000-trained_model-13-12_37.pth
# 0     636  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1311  /130000-trained_model-13-09_42.pth
# 14   1212  /160000-trained_model-17-16_12.pth
# 1    1059  /130000-trained_model-17-00_44.pth
# 3     942  /230000-trained_model-13-12_37.pth
# 0     651  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1326  /130000-trained_model-13-09_42.pth
# 14   1227  /160000-trained_model-17-16_12.pth
# 1    1059  /130000-trained_model-17-00_44.pth
# 3     948  /230000-trained_model-13-12_37.pth
# 0     648  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1326  /130000-trained_model-13-09_42.pth
# 14   1227  /160000-trained_model-17-16_12.pth
# 1    1059  /130000-trained_model-17-00_44.pth
# 3     951  /230000-trained_model-13-12_37.pth
# 0     651  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1329  /130000-trained_model-13-09_42.pth
# 14   1227  /160000-trained_model-17-16_12.pth
# 1    1062  /130000-trained_model-17-00_44.pth
# 3     951  /230000-trained_model-13-12_37.pth
# 0     654  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1329  /130000-trained_model-13-09_42.pth
# 14   1230  /160000-trained_model-17-16_12.pth
# 1    1062  /130000-trained_model-17-00_44.pth
# 3     966  /230000-trained_model-13-12_37.pth
# 0     657  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1362  /130000-trained_model-13-09_42.pth
# 14   1248  /160000-trained_model-17-16_12.pth
# 1    1080  /130000-trained_model-17-00_44.pth
# 3     981  /230000-trained_model-13-12_37.pth
# 0     678  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1371  /130000-trained_model-13-09_42.pth
# 14   1251  /160000-trained_model-17-16_12.pth
# 1    1083  /130000-trained_model-17-00_44.pth
# 3     987  /230000-trained_model-13-12_37.pth
# 0     678  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1371  /130000-trained_model-13-09_42.pth
# 14   1248  /160000-trained_model-17-16_12.pth
# 1    1083  /130000-trained_model-17-00_44.pth
# 3     993  /230000-trained_model-13-12_37.pth
# 0     684  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1371  /130000-trained_model-13-09_42.pth
# 14   1254  /160000-trained_model-17-16_12.pth
# 1    1083  /130000-trained_model-17-00_44.pth
# 3     996  /230000-trained_model-13-12_37.pth
# 0     693  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1377  /130000-trained_model-13-09_42.pth
# 14   1254  /160000-trained_model-17-16_12.pth
# 1    1083  /130000-trained_model-17-00_44.pth
# 3     996  /230000-trained_model-13-12_37.pth
# 0     690  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1380  /130000-trained_model-13-09_42.pth
# 14   1260  /160000-trained_model-17-16_12.pth
# 1    1083  /130000-trained_model-17-00_44.pth
# 3     999  /230000-trained_model-13-12_37.pth
# 0     699  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1383  /130000-trained_model-13-09_42.pth
# 14   1269  /160000-trained_model-17-16_12.pth
# 1    1086  /130000-trained_model-17-00_44.pth
# 3    1002  /230000-trained_model-13-12_37.pth
# 0     705  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1383  /130000-trained_model-13-09_42.pth
# 14   1269  /160000-trained_model-17-16_12.pth
# 1    1086  /130000-trained_model-17-00_44.pth
# 3    1002  /230000-trained_model-13-12_37.pth
# 0     705  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1389  /130000-trained_model-13-09_42.pth
# 14   1275  /160000-trained_model-17-16_12.pth
# 1    1092  /130000-trained_model-17-00_44.pth
# 3    1005  /230000-trained_model-13-12_37.pth
# 0     711  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1398  /130000-trained_model-13-09_42.pth
# 14   1302  /160000-trained_model-17-16_12.pth
# 1    1092  /130000-trained_model-17-00_44.pth
# 3    1005  /230000-trained_model-13-12_37.pth
# 0     711  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1398  /130000-trained_model-13-09_42.pth
# 14   1302  /160000-trained_model-17-16_12.pth
# 1    1095  /130000-trained_model-17-00_44.pth
# 3    1008  /230000-trained_model-13-12_37.pth
# 0     711  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1404  /130000-trained_model-13-09_42.pth
# 14   1314  /160000-trained_model-17-16_12.pth
# 1    1101  /130000-trained_model-17-00_44.pth
# 3    1020  /230000-trained_model-13-12_37.pth
# 0     711  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1407  /130000-trained_model-13-09_42.pth
# 14   1329  /160000-trained_model-17-16_12.pth
# 1    1107  /130000-trained_model-17-00_44.pth
# 3    1035  /230000-trained_model-13-12_37.pth
# 0     714  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1407  /130000-trained_model-13-09_42.pth
# 14   1329  /160000-trained_model-17-16_12.pth
# 1    1116  /130000-trained_model-17-00_44.pth
# 3    1041  /230000-trained_model-13-12_37.pth
# 0     717  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1431  /130000-trained_model-13-09_42.pth
# 14   1338  /160000-trained_model-17-16_12.pth
# 1    1143  /130000-trained_model-17-00_44.pth
# 3    1050  /230000-trained_model-13-12_37.pth
# 0     723  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1446  /130000-trained_model-13-09_42.pth
# 14   1341  /160000-trained_model-17-16_12.pth
# 1    1149  /130000-trained_model-17-00_44.pth
# 3    1062  /230000-trained_model-13-12_37.pth
# 0     729  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1458  /130000-trained_model-13-09_42.pth
# 14   1353  /160000-trained_model-17-16_12.pth
# 1    1146  /130000-trained_model-17-00_44.pth
# 3    1071  /230000-trained_model-13-12_37.pth
# 0     732  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1470  /130000-trained_model-13-09_42.pth
# 14   1365  /160000-trained_model-17-16_12.pth
# 1    1164  /130000-trained_model-17-00_44.pth
# 3    1080  /230000-trained_model-13-12_37.pth
# 0     729  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1476  /130000-trained_model-13-09_42.pth
# 14   1365  /160000-trained_model-17-16_12.pth
# 1    1170  /130000-trained_model-17-00_44.pth
# 3    1092  /230000-trained_model-13-12_37.pth
# 0     726  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1476  /130000-trained_model-13-09_42.pth
# 14   1368  /160000-trained_model-17-16_12.pth
# 1    1170  /130000-trained_model-17-00_44.pth
# 3    1092  /230000-trained_model-13-12_37.pth
# 0     726  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1497  /130000-trained_model-13-09_42.pth
# 14   1395  /160000-trained_model-17-16_12.pth
# 1    1197  /130000-trained_model-17-00_44.pth
# 3    1110  /230000-trained_model-13-12_37.pth
# 0     735  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1506  /130000-trained_model-13-09_42.pth
# 14   1398  /160000-trained_model-17-16_12.pth
# 1    1191  /130000-trained_model-17-00_44.pth
# 3    1110  /230000-trained_model-13-12_37.pth
# 0     738  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1512  /130000-trained_model-13-09_42.pth
# 14   1401  /160000-trained_model-17-16_12.pth
# 1    1197  /130000-trained_model-17-00_44.pth
# 3    1110  /230000-trained_model-13-12_37.pth
# 0     747  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1518  /130000-trained_model-13-09_42.pth
# 14   1401  /160000-trained_model-17-16_12.pth
# 1    1200  /130000-trained_model-17-00_44.pth
# 3    1110  /230000-trained_model-13-12_37.pth
# 0     750  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1527  /130000-trained_model-13-09_42.pth
# 14   1407  /160000-trained_model-17-16_12.pth
# 1    1200  /130000-trained_model-17-00_44.pth
# 3    1119  /230000-trained_model-13-12_37.pth
# 0     762  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1527  /130000-trained_model-13-09_42.pth
# 14   1407  /160000-trained_model-17-16_12.pth
# 1    1206  /130000-trained_model-17-00_44.pth
# 3    1119  /230000-trained_model-13-12_37.pth
# 0     765  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1527  /130000-trained_model-13-09_42.pth
# 14   1407  /160000-trained_model-17-16_12.pth
# 1    1206  /130000-trained_model-17-00_44.pth
# 3    1119  /230000-trained_model-13-12_37.pth
# 0     765  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1527  /130000-trained_model-13-09_42.pth
# 14   1407  /160000-trained_model-17-16_12.pth
# 1    1206  /130000-trained_model-17-00_44.pth
# 3    1119  /230000-trained_model-13-12_37.pth
# 0     765  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1530  /130000-trained_model-13-09_42.pth
# 14   1416  /160000-trained_model-17-16_12.pth
# 1    1206  /130000-trained_model-17-00_44.pth
# 3    1113  /230000-trained_model-13-12_37.pth
# 0     765  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1530  /130000-trained_model-13-09_42.pth
# 14   1416  /160000-trained_model-17-16_12.pth
# 1    1212  /130000-trained_model-17-00_44.pth
# 3    1113  /230000-trained_model-13-12_37.pth
# 0     765  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1527  /130000-trained_model-13-09_42.pth
# 14   1413  /160000-trained_model-17-16_12.pth
# 1    1215  /130000-trained_model-17-00_44.pth
# 3    1113  /230000-trained_model-13-12_37.pth
# 0     768  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1527  /130000-trained_model-13-09_42.pth
# 14   1413  /160000-trained_model-17-16_12.pth
# 1    1215  /130000-trained_model-17-00_44.pth
# 3    1116  /230000-trained_model-13-12_37.pth
# 0     768  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1533  /130000-trained_model-13-09_42.pth
# 14   1419  /160000-trained_model-17-16_12.pth
# 1    1218  /130000-trained_model-17-00_44.pth
# 3    1119  /230000-trained_model-13-12_37.pth
# 0     768  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1539  /130000-trained_model-13-09_42.pth
# 14   1428  /160000-trained_model-17-16_12.pth
# 1    1215  /130000-trained_model-17-00_44.pth
# 3    1122  /230000-trained_model-13-12_37.pth
# 0     765  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1536  /130000-trained_model-13-09_42.pth
# 14   1431  /160000-trained_model-17-16_12.pth
# 1    1218  /130000-trained_model-17-00_44.pth
# 3    1122  /230000-trained_model-13-12_37.pth
# 0     765  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1545  /130000-trained_model-13-09_42.pth
# 14   1437  /160000-trained_model-17-16_12.pth
# 1    1227  /130000-trained_model-17-00_44.pth
# 3    1122  /230000-trained_model-13-12_37.pth
# 0     768  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1557  /130000-trained_model-13-09_42.pth
# 14   1446  /160000-trained_model-17-16_12.pth
# 1    1230  /130000-trained_model-17-00_44.pth
# 3    1119  /230000-trained_model-13-12_37.pth
# 0     786  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1566  /130000-trained_model-13-09_42.pth
# 14   1449  /160000-trained_model-17-16_12.pth
# 1    1230  /130000-trained_model-17-00_44.pth
# 3    1134  /230000-trained_model-13-12_37.pth
# 0     786  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1584  /130000-trained_model-13-09_42.pth
# 14   1461  /160000-trained_model-17-16_12.pth
# 1    1230  /130000-trained_model-17-00_44.pth
# 3    1143  /230000-trained_model-13-12_37.pth
# 0     792  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1590  /130000-trained_model-13-09_42.pth
# 14   1461  /160000-trained_model-17-16_12.pth
# 1    1242  /130000-trained_model-17-00_44.pth
# 3    1146  /230000-trained_model-13-12_37.pth
# 0     795  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1593  /130000-trained_model-13-09_42.pth
# 14   1479  /160000-trained_model-17-16_12.pth
# 1    1242  /130000-trained_model-17-00_44.pth
# 3    1146  /230000-trained_model-13-12_37.pth
# 0     807  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1602  /130000-trained_model-13-09_42.pth
# 14   1482  /160000-trained_model-17-16_12.pth
# 1    1248  /130000-trained_model-17-00_44.pth
# 3    1152  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1626  /130000-trained_model-13-09_42.pth
# 14   1488  /160000-trained_model-17-16_12.pth
# 1    1254  /130000-trained_model-17-00_44.pth
# 3    1155  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1629  /130000-trained_model-13-09_42.pth
# 14   1491  /160000-trained_model-17-16_12.pth
# 1    1254  /130000-trained_model-17-00_44.pth
# 3    1155  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1632  /130000-trained_model-13-09_42.pth
# 14   1491  /160000-trained_model-17-16_12.pth
# 1    1257  /130000-trained_model-17-00_44.pth
# 3    1158  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1632  /130000-trained_model-13-09_42.pth
# 14   1491  /160000-trained_model-17-16_12.pth
# 1    1257  /130000-trained_model-17-00_44.pth
# 3    1164  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1635  /130000-trained_model-13-09_42.pth
# 14   1491  /160000-trained_model-17-16_12.pth
# 1    1260  /130000-trained_model-17-00_44.pth
# 3    1164  /230000-trained_model-13-12_37.pth
# 0     801  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1638  /130000-trained_model-13-09_42.pth
# 14   1491  /160000-trained_model-17-16_12.pth
# 1    1260  /130000-trained_model-17-00_44.pth
# 3    1167  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1650  /130000-trained_model-13-09_42.pth
# 14   1497  /160000-trained_model-17-16_12.pth
# 1    1281  /130000-trained_model-17-00_44.pth
# 3    1179  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth
#     score                           name_sort
# 10   1659  /130000-trained_model-13-09_42.pth
# 14   1503  /160000-trained_model-17-16_12.pth
# 1    1287  /130000-trained_model-17-00_44.pth
# 3    1185  /230000-trained_model-13-12_37.pth
# 0     804  /330000-trained_model-13-16_13.pth

# %%
# 4   130000-trained_model-13-09_42.pth    918
# 5   130000-trained_model-17-00_44.pth    897
# 8   160000-trained_model-17-16_12.pth    771
# 10  230000-trained_model-13-12_37.pth    738
# 14  330000-trained_model-13-16_13.pth    468

# %%
x = np.array([0,0,0,0,0])
x

# %%
# Out:
# /kaggle/input/mangala-models-firstnewdqn/330000-trained_model-13-16_13.pth
# /kaggle/input/mangala-models-firstnewdqn/130000-trained_model-17-00_44.pth
# /kaggle/input/mangala-models-firstnewdqn/410000-trained_model-17-07_25.pth
# /kaggle/input/mangala-models-firstnewdqn/230000-trained_model-13-12_37.pth
# /kaggle/input/mangala-models-firstnewdqn/30000-trained_model-13-07_19.pth
# /kaggle/input/mangala-models-firstnewdqn/140000-trained_model-17-15_07.pth
# /kaggle/input/mangala-models-firstnewdqn/630000-trained_model-13-23_37.pth
# /kaggle/input/mangala-models-firstnewdqn/1010000-trained_model-14-10_57.pth
# /kaggle/input/mangala-models-firstnewdqn/320000-trained_model-17-16_41.pth
# /kaggle/input/mangala-models-firstnewdqn/730000-trained_model-14-01_40.pth
# /kaggle/input/mangala-models-firstnewdqn/130000-trained_model-13-09_42.pth
# /kaggle/input/mangala-models-firstnewdqn/260000-trained_model-17-15_18.pth
# /kaggle/input/mangala-models-firstnewdqn/530000-trained_model-13-21_08.pth
# /kaggle/input/mangala-models-firstnewdqn/180000-trained_model-17-17_03.pth
# /kaggle/input/mangala-models-firstnewdqn/27000.trained_model4.22
# /kaggle/input/mangala-models-firstnewdqn/160000-trained_model-17-16_12.pth
# /kaggle/input/mangala-models-firstnewdqn/930000-trained_model-14-08_16.pth
# /kaggle/input/mangala-models-firstnewdqn/340000-trained_model-17-17_08.pth
# /kaggle/input/mangala-models-firstnewdqn/290000-trained_model-17-04_37.pth
# /kaggle/input/mangala-models-firstnewdqn/-300000-trained_model-17-16_14.pth
# /kaggle/input/mangala-models-firstnewdqn/1030000-trained_model-14-13_19.pth
# /kaggle/input/mangala-models-firstnewdqn/230000-trained_model-17-20_20.pth
# /kaggle/input/mangala-models-firstnewdqn/1430000-trained_model-16-16_14.pth
# /kaggle/input/mangala-models-firstnewdqn/830000-trained_model-14-04_41.pth
# /kaggle/input/mangala-models-firstnewdqn/1670000-trained_model-17-00_11.pth
# /kaggle/input/mangala-models-firstnewdqn/430000-trained_model-13-18_42.pth
# /kaggle/input/mangala-models-firstnewdqn/120000-trained_model-14-20_11.pth
